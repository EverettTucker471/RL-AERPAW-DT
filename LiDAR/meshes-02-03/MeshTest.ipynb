# %%
import sionna
from sionna.rt import load_scene

# %%
scene = load_scene("/home/everetttucker/Documents/meshes-02-03/lake-wheeler-scene.xml")
scene.preview()
# Out:
# <span style="font-family: monospace; color: #f55">2026-02-03 14:08:05 WARN  wrk3  [PLYMesh] &quot;lake-wheeler-terrain-mesh-output.ply&quot;: performance warning -- this file uses the ASCII PLY format, which is slow to parse. Consider converting it to the binary PLY format.</span>
# <span style="font-family: monospace; color: #f55">2026-02-03 14:09:08 WARN  wrk3  [PLYMesh] &quot;lake-wheeler-terrain-mesh-output.ply&quot;: Mesh attribute &quot;vertex_color&quot; has integer fields: color attributes are expected to be in the [0, 1] range.</span>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 scene = load_scene("/home/everetttucker/Documents/meshes-02-03/lake-wheeler-scene.xml")
#       2 scene.preview()
#
# File ~/miniconda3/envs/RL-DT/lib/python3.12/site-packages/sionna/rt/scene.py:1054, in load_scene(filename, merge_shapes, merge_shapes_exclude_regex)
#    1052 try:
#    1053     thread.set_file_resolver(fres)
# -> 1054     mi_scene = mi.load_string(processed)
#    1055 finally:
#    1056     thread.set_file_resolver(fres_old)
#
# RuntimeError: ​[xml.cpp:1078] Error while loading "<string>" (near line 18, col 10): could not instantiate shape plugin of type "ply":
# [xml.cpp:1078]   [PLYMesh] Error while loading PLY file "lake-wheeler-buildings-ascii.ply":
# [xml.cpp:1078] [PLYMesh]   [PLYMesh] "lake-wheeler-buildings-ascii.ply": could not parse "uchar" value for field vertex_indices.count (may be due to non-triangular faces)!
